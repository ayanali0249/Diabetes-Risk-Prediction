# %%
# !pip install shap

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import shap
import pickle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: shap in c:\users\ayana\appdata\roaming\python\python313\site-packages (0.48.0)
# Requirement already satisfied: numpy in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (2.2.2)
# Requirement already satisfied: scipy in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (1.15.1)
# Requirement already satisfied: scikit-learn in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in c:\users\ayana\appdata\roaming\python\python313\site-packages (from shap) (4.12.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: colorama in c:\users\ayana\appdata\roaming\python\python313\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayana\appdata\roaming\python\python313\site-packages (from scikit-learn->shap) (3.5.0)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~illow (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ayana\AppData\Roaming\Python\Python313\site-packages)

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
           'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df = pd.read_csv(url, names=columns)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df[
    ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.nan)
df.fillna(df.median(), inplace=True)

X = df.drop('Outcome', axis=1)
y = df['Outcome']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7402597402597403
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80        99
#            1       0.63      0.65      0.64        55
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.72      0.72       154
# weighted avg       0.74      0.74      0.74       154
#
# Confusion Matrix:
#  [[78 21]
#  [19 36]]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Feature Importance")
plt.show()

# %%
import shap

# Use new unified API and disable additivity check
explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_test, check_additivity=False)

shap.summary_plot(shap_values, X_test, feature_names=X.columns)

# %%
pickle.dump(model, open('diabetes_model.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))
